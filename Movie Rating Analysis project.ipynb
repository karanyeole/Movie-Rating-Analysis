# %% [markdown]
# # Movie Rating Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
''' matplotlib = visualization
    seaborn = advance visualization
    numpy = multidimention array
    pandas = dataframe '''
# Out:
# ' matplotlib = visualization\n    seaborn = advance visualization\n    numpy = multidimention array\n    pandas = dataframe '

# %% [markdown]
# # Project
# # working on movie rating analysis
# # working on advanced visualization

# %%
import pandas as pd
import os

# %%
movies=pd.read_csv(r"C:\Users\Karan G Yeole\Downloads\Movie-Rating.csv")

# %%
len(movies)
# Out:
# 559

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film=movies.Film.astype('category')  # Convert the datatype using astype
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline  '''All the plot should inside the line'''
import warnings 
warnings.filterwarning('ignore')
# Out:
# UsageError: unrecognized arguments: '''All the plot should inside the line'''

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='hex')

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind='reg')

# %%
m1=sns.distplot(movies.AudienceRating)
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\3511340563.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1=sns.distplot(movies.AudienceRating)

# %%
m1=sns.distplot(movies.CriticRating)
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\311962247.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1=sns.distplot(movies.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movies.AudienceRating,bins=20)
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\1503470578.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m2=sns.distplot(movies.AudienceRating,bins=20)

# %%
 n1=plt.hist(movies.AudienceRating,bins=15)

# %%
sns.set_style('white')
n1=plt.hist(movies.AudienceRating,bins=20)

# %%
n1=plt.hist(movies.CriticRating,bins=20)

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
vis1=sns.lmplot(data=movies,x="CriticRating",y='AudienceRating',fit_reg=False,hue='Genre')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
vis1=sns.lmplot(data=movies,x="CriticRating",y='AudienceRating',fit_reg=True,hue='Genre')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
vis1 = sns.lmplot(data=movies, x="CriticRating", y='AudienceRating', fit_reg=True, hue='Genre', height=10)
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#KDE plot kernel density plot

k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=False, shade_lowest=True, cmap='Reds')
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\3812100545.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=False, shade_lowest=True, cmap='Reds')
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\3812100545.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=False, shade_lowest=True, cmap='Reds')

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds')
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\1073030985.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds')
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\1073030985.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade=True, shade_lowest=False, cmap='Reds')

# %%
k2 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade_lowest=False, cmap='Greens_r')
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\3442201288.py:1: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.05.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k2 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRating', shade_lowest=False, cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', shade_lowest=True, cmap='Greens_r')
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\2149339497.py:2: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k1 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', shade_lowest=True, cmap='Greens_r')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating')

# %%
k2=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating')

# %%
f,ax=plt.subplots(3,3,figsize=(12,7))

# %%
f,axes=plt.subplots(1,2,figsize=(10,5))
k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',ax=axes[0])
k2=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax=axes[1])

# %%
# boxplot

w=sns.boxplot(data=movies,x='Genre',y='CriticRating')

# %%
z=sns.violinplot(data=movies,x='Genre',y='CriticRating')

# %%
w1=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='AudienceRating')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(data=movies,x='CriticRating',y='AudienceRating')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')
# Out:
# D:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f,axes=plt.subplots(2,2,figsize=(15,15))

k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',
               shade=True,shade_lowest=True,cmap='cool',ax=axes[0,0])

k2=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',
               shade=True,shade_lowest=True,cmap='inferno',ax=axes[0,1])

k2b=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',
               cmap='cool',ax=axes[1,0])

z=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',
                 y='CriticRating',ax=axes[1,0])

k4=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',
               shade=True,shade_lowest=False,cmap='Blues_r',
                 ax=axes[1,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))
plt.show()
# Out:
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\2991965018.py:4: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\2991965018.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',
# C:\Users\Karan G Yeole\AppData\Local\Temp\ipykernel_24404\2991965018.py:7: UserWarning:
#
# `shade_lowest` has been replaced by `thresh`; setting `thresh=0.
# This will become an error in seaborn v0.13.0; please update your code.
#
#   k2=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',
# ...
